# %%
import os
path = r"C:\Users\97155\Desktop\IU\Updated_December_data"
files = os.listdir(path)

# %%
vals = files[23:29]

# %%
files = vals + files

# %%
files = files[:29]

# %%
files_xls = [f for f in files if f[-4:] == 'xlsx']
files_xls = files_xls
files_xls
# Out:
# ['Updated_Cloud_data_for_4th_December.xlsx',
#  'Updated_Cloud_data_for_5th_December.xlsx',
#  'Updated_Cloud_data_for_6th_December.xlsx',
#  'Updated_Cloud_data_for_7th_December.xlsx',
#  'Updated_Cloud_data_for_8th_December.xlsx',
#  'Updated_Cloud_data_for_9th_December.xlsx',
#  'Updated_Cloud_data_for_10th_December.xlsx',
#  'Updated_Cloud_data_for_11th_December.xlsx',
#  'Updated_Cloud_data_for_12th_December.xlsx',
#  'Updated_Cloud_data_for_13th_December.xlsx',
#  'Updated_Cloud_data_for_14th_December.xlsx',
#  'Updated_Cloud_data_for_15th_December.xlsx',
#  'Updated_Cloud_data_for_16th_December.xlsx',
#  'Updated_Cloud_data_for_17th_December.xlsx',
#  'Updated_Cloud_data_for_18th_December.xlsx',
#  'Updated_Cloud_data_for_19th_December.xlsx',
#  'Updated_Cloud_data_for_20th_December.xlsx',
#  'Updated_Cloud_data_for_21th_December.xlsx',
#  'Updated_Cloud_data_for_22th_December.xlsx',
#  'Updated_Cloud_data_for_23th_December.xlsx',
# ...

# %%
week1 = files_xls[0:7]
week2 = files_xls[7:14]
week3 = files_xls[14:21]
week4 = files_xls[21:28]

# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_excel(r"C:\Users\97155\Desktop\IU\Updated_December_data\Updated_Cloud_data_for_4th_December.xlsx")
# df2 = pd.read_excel(r"C:\Users\97155\Desktop\IU\Updated_December_data\Updated_Cloud_data_for_5th_December.xlsx")

# %%
week1_dfs = []
for i in week1:
    df = pd.read_excel(i)
    week1_dfs.append(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [125], in <cell line: 2>()
#       1 week1_dfs = []
#       2 for i in week1:
# ----> 3     df = pd.read_excel(i)
#       4     week1_dfs.append(df)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
test = pd.concat([df,df2],axis=0)

# %%
test = test.drop_duplicates()

# %%
test
# Out:
#       Unnamed: 0  _2day_axial_slope  _2day_axial_slope_confidence  \
# 0              0          -0.096095                      0.097497
# 1              0           0.138639                      0.198956
# 2              0           0.000000                      0.000000
# 3              0          -0.425076                      0.160199
# 4              0          -0.570498                      0.421479
# ...          ...                ...                           ...
# 8496           0          -0.063034                      0.005145
# 8497           0          -0.074853                      0.025369
# 8498           0           0.021658                      0.001290
# 8499           0           0.339880                      0.054888
# 8500           0           0.256180                      0.044998
#
#       _2day_vertical_slope  _2day_vertical_slope_confidence  \
# 0                -0.036879                         0.031194
# ...

# %%
# def combine_week(filename):
#     df = pd.read_excel(filename)
